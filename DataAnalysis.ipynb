# %%
import pandas as pd
import sqlite3 as sql
import numpy as np
from datetime import datetime
import plotly.graph_objects as go
import pandas_ta as ta
import matplotlib
import requests
from random import randint

# %%
all_df = pd.read_sql('SELECT *, datetime(date,"localtime") FROM inv_hist_quotes', con=sql.connect('mydb.db'))
# all_df['date'] = all_df['date'].apply(lambda x : datetime.strptime(x, '%d-%m-%Y'))
all_df['date']
# Out:
# 0        14-04-2022
# 1        13-04-2022
# 2        12-04-2022
# 3        11-04-2022
# 4        10-04-2022
#             ...
# 28792    08-01-2010
# 28793    07-01-2010
# 28794    06-01-2010
# 28795    05-01-2010
# 28796    04-01-2010
# Name: date, Length: 28797, dtype: object

# %%
all_df['name'].unique()
# Out:
# array(['United States 10-Year', 'United States 30-Year',
#        'Direxion Daily S&P 500® Bear 3X Shares',
#        'Dow Jones Industrial Average', 'Dow Jones Small-Cap',
#        'Dow Jones Mid-Cap', 'Dow Jones Large-Cap', 'Gold Spot US Dollar',
#        'Crude Oil WTI Futures'], dtype=object)

# %%
dji_df = all_df[all_df['name'] == 'Dow Jones Industrial Average']
dji_df.sort_values(by=['date'], ascending=False)
dji_df_sl = dji_df[dji_df['date'].between(datetime(2018,4,14), datetime(2022,4,14))]

# %%
fig = go.Figure(data=[ 
    go.Scatter(
        x=dji_df_sl['date'], 
        y=dji_df_sl['close'],
        line=dict(
            color='green', 
            width=1)
        ),
    go.Scatter(
        x=dji_df_sl['date'], 
        y=dji_df_sl['close'],
        line=dict(
            color='red', 
            width=1)
        )
    ])

fig.add_hline(y=dji_df_sl['close'].std())

fig.show()
